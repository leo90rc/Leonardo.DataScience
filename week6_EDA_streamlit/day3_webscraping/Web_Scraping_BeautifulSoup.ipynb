# %% [markdown]
# Antes de empezar: un poco de documentación para enterder ligeramente cómo funciona HTML: https://www.w3schools.com/html/html_intro.asp

# %% [markdown]
# # Web Scraping: Beautiful Soup

# %% [markdown]
# **Beautiful Soup** es una librería **Python** que permite extraer información de contenido en formato **HTML o XML**. Para usarla, es necesario especificar un **parser**, que es responsable de transformar un documento HTML o XML en un árbol complejo de objetos Python. Esto permite, por ejemplo, que podamos interactuar con los elementos de una página web como si estuviésemos utilizando las herramientas del desarrollador de un navegador.
#
# A la hora de extraer información de una web, uno de los parsers más utilizado es el parser HTML de **lxml**. Precisamente, será el que utilicemos en este tutorial.

# %% [markdown]
# **Será necesario instalar las siguientes librerías** (si no las tienes ya):
#
#         pip3 install beautifulsoup4 requests pandas
#
#         pip3 install beautifulsoup4
#
#         pip3 install requests
#
#         pip3 install pandas

# %% [markdown]
# ###  Pasos a seguir en el proceso de 'scraping':
#
# 1. Encuentra la URL que quieres 'escrapear'.
# 2. Inspecciona la página (código fuente).
# 3. Localiza los datos que necesitas obtener.
# 4. Desarrolla tu código en Python.
#     1. Crea tu sopa
#     2. Busca los elementos que cotienen los datos y extráelos
# 5. Ejecuta tu código y obten los datos.
# 6. Alamacena los datos en el formato requerido.

# %% [markdown]
# Algunos ejemplos de Web Scraping utilizando Beautiful Soup:
#
# https://j2logo.com/python/web-scraping-con-python-guia-inicio-beautifulsoup/
#
# http://omz-software.com/pythonista/docs/ios/beautifulsoup_guide.html
#
# https://towardsdatascience.com/top-5-beautiful-soup-functions-7bfe5a693482
#
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/

# %%
# Importamos librerías
import requests
from bs4 import BeautifulSoup
import pandas as pd
import html
import numpy as np

# %% [markdown]
# ## Caso 1: Scraping de un catálogo: Labirratorium

# %%
URL = 'https://www.labirratorium.com/es/67-cervezas-por-estilo?page='

# %% [markdown]
# Queremos obtener un dataFrame con todas las cervezas del catálogo y sus características descritas. Analizamos la página para ver qué tenemos que hacer para conseguirlo

# %%
# La web tiene 80 páginas con 12 cervezas listadas en cada página.

# %% [markdown]
# Hacemos la consulta (request) y creamos la SOPA inicial:

# %%
r = requests.get(URL)
soup = BeautifulSoup(r.text, 'lxml')

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
soup

# %%
# Guardamos lista de cervezas
cervezas_grid = soup.find_all(class_ = 'product-image')
len(cervezas_grid)
# Out:
# 12

# %%
# necesitamos acceder a cada una de las cervezas del grid:
lista_URL = []
for cerveza in cervezas_grid:
    URL_cerveza = cerveza.find('a')['href']
    lista_URL.append(URL_cerveza)
lista_URL
# Out:
# ['https://www.labirratorium.com/es/lambic/284-boon-kriek-2013.html',
#  'https://www.labirratorium.com/es/alemania/225-stortebeker-schwarz-bier.html',
#  'https://www.labirratorium.com/es/inicio/199-orval.html',
#  'https://www.labirratorium.com/es/alemania/184-augustiner-lagerbier-hell.html',
#  'https://www.labirratorium.com/es/inicio/183-schneider-eisbock.html',
#  'https://www.labirratorium.com/es/inicio/181-schlenkerla-rauchbier-weizen.html',
#  'https://www.labirratorium.com/es/inicio/173-samuel-adams-boston-lager.html',
#  'https://www.labirratorium.com/es/inicio/165-laugar-epa.html',
#  'https://www.labirratorium.com/es/inicio/82-westmalle-dubbel.html',
#  'https://www.labirratorium.com/es/inicio/75-duchesse-de-bourgogne.html',
#  'https://www.labirratorium.com/es/inicio/61-tripel-karmeliet33.html',
#  'https://www.labirratorium.com/es/inicio/21-weihenstephaner-vitus.html']

# %%
# Hacemos un nuevo request para la primera cerveza: 
r = requests.get(lista_URL[0])
soup_cerveza = BeautifulSoup(r.text, 'lxml')

# %%
# Nombre
nombre = soup_cerveza.find(class_ = 'h1 product-detail-name').text
print(nombre)
# Out:
# Boon Oude Kriek 37,5cl

# %%
# Precio
precio = soup_cerveza.find(class_ = 'current-price').find('span')['content']
precio
# Out:
# '7.15'

# %%
# Descripcion corta
descrp_corta = soup_cerveza.find(class_ = 'description-short').find('p').text
descrp_corta
# Out:
# 'Lambic / Kriek'

# %%
# Descripción larga
descrp_larga = soup_cerveza.find(class_ = 'product-description').find('p').text
descrp_larga
# Out:
# 'Cerveza de fermentación espontánea (Lambic) de 6.5% ABV sin filtrar ni pasteurizar de estilo Kriek, elaborada con cerezas naturales.'

# %%
# Imagen
imagen = soup_cerveza.find(class_ = 'product-cover').find(id = 'zoom_product')['src']
imagen
# Out:
# 'https://www.labirratorium.com/19351-large_default/boon-kriek-2013.jpg'

# %%
# Otra forma de obtener la imagen (así lo hizo Borja)

imagen2 = soup_cerveza.find(class_ ='js-qv-product-cover img-fluid')['src']
imagen2
# Out:
# 'https://www.labirratorium.com/19351-large_default/boon-kriek-2013.jpg'

# %%
 # Brand

marca = soup_cerveza.find(class_ = 'img img-thumbnail manufacturer-logo')['alt']
marca
# Out:
# 'Brouwerij F. Boon'

# %%
# Código de barras

# %%
# Features

features = soup_cerveza.find(class_ = 'data-sheet')
features_dic = {}
features_dt = features.find_all('dt')
features_dd = features.find_all('dd')
for feature, value in zip(features_dt, features_dd):
    features_dic[feature.text] = value.text
features_dic
# Out:
# {'Estilo': 'KRIEK',
#  'Origen': 'Bélgica',
#  '% Alc.': '6.5\nALTO (6-9%)',
#  'Otros ingredientes': 'Cerezas Naturales',
#  'Volumen (cl)': '37.5 Cl',
#  'Tipo Fermentación': 'Lambic (Fermentación espontánea o salvaje)',
#  'Maltas': 'Cebada y Trigo',
#  'IBU': '0-25 Amargor bajo',
#  'Color': 'Rojiza',
#  'Envase': 'Botella'}

# %% [markdown]
# # Probar otra manera de crear ese mismo diccionario de arriba

# %%
# Creamos un Id único que os permita diferenciar cada entrada en la BBDD

id_cerv = 'lbt_' + str()

# %% [markdown]
# Ya tenemos todos los datos que queremos de la cerveza: Agrupamos todo en una lista:

# %%
# Agregamos a una lista

pages = np.arrange(1,81)
count = 1
lista_cervezas = []

for page in pages:

    URL = 'https://www.labirratorium.com/es/67-cervezas-por-estilo?page=' + str(page)
    r = requests.get(URL)
    soup = BeautifulSoup(r.text, 'lxml')
    type(soup)

    # Guardamos lista de cervezas
    cervezas_grid = soup.find_all(class_ = 'product-image')
    len(cervezas_grid)

    # necesitamos acceder a cada una de las cervezas del grid:
    
    for cerveza in cervezas_grid:
        URL_cerveza = cerveza.find('a')['href']

    # Hacemos un nuevo request para la primera cerveza: 
        r = requests.get(lista_URL[0])
        soup_cerveza = BeautifulSoup(r.text, 'lxml')

    # Nombre
        nombre = soup_cerveza.find(class_ = 'h1 product-detail-name').text
        print(nombre)

        # Precio
        precio = soup_cerveza.find(class_ = 'current-price').find('span')['content']
        precio

        # Descripción corta
        try:
            descrp_corta = soup_cerveza.find(class_ = 'description-short').find('p').text
        except:
            descrp_corta = None

        # Descripción larga
        try:
            descrp_larga = soup_cerveza.find(class_ = 'product-description').find('p').text
        except:
            descrp_larga = None

        # Otra forma de obtener la imagen (así lo hizo Borja)
        imagen2 = soup_cerveza.find(class_ ='js-qv-product-cover img-fluid')['src']
        imagen2

        # Brand
        marca = soup_cerveza.find(class_ = 'img img-thumbnail manufacturer-logo')['alt']
        marca

        # Features
        features = soup_cerveza.find(class_ = 'data-sheet')
        features_dic = {}
        features_dt = features.find_all('dt')
        features_dd = features.find_all('dd')
        for feature, value in zip(features_dt, features_dd):
            features_dic[feature.text] = value.text
        features_dic

# %%
# CODIGO QUE PASO BORJA POR DISCORD

pages = np.arange(1,81)
count = 1
lista_cervezas = []

for page in pages:

    URL = 'https://www.labirratorium.com/es/67-cervezas-por-estilo?page=' + str(page)
    r = requests.get(URL)
    soup = BeautifulSoup(r.text, 'lxml')
    cervezas_grid = soup.find_all(class_='product-image')

    count_beer = 1

    for cerveza in cervezas_grid:

        print('Cerveza {} de {}, pag {}/{}'.format(count_beer, len(cervezas_grid), page, len(pages)))

        URL_cerveza = cerveza.find('a')['href']
        r = requests.get(URL_cerveza)
        soup_cerveza = BeautifulSoup(r.text, 'lxml')

        id_cerv = 'lbt_' + str(count)

        name = soup_cerveza.find(class_='h1 product-detail-name').text   

        price = soup_cerveza.find(class_='current-price').find('span')['content']

        try:
            descr_short = soup_cerveza.find(class_='description-short').find('p').text
        except:
            descr_short = None

        image = soup_cerveza.find(class_='js-qv-product-cover img-fluid')['src']

        try:
            brand = soup_cerveza.find(class_='img img-thumbnail manufacturer-logo')['alt']
        except:
            brand = None

        features_dicc = {}
        try:
            features = soup_cerveza.find(class_ = 'data-sheet')
            features_dt = features.find_all('dt')
            features_dd = features.find_all('dd')
            for feature, value in zip(features_dt, features_dd):
                #print(feature.text, value.text)
                features_dicc[feature.text] = value.text
        except:
            features_dicc = {}

        lista_cervezas.append([
            ('id', id_cerv),
            ('name', name), 
            ('price', price),
            ('descr_short', descr_short),
            ('image', image),
            ('brand', brand),
            ('features', features_dicc)])

        count += 1
        count_beer += 1
# Out:
# Cerveza 1 de 12, pag 1/80
# Cerveza 2 de 12, pag 1/80
# Cerveza 3 de 12, pag 1/80
# Cerveza 4 de 12, pag 1/80
# Cerveza 5 de 12, pag 1/80
# Cerveza 6 de 12, pag 1/80
# Cerveza 7 de 12, pag 1/80
# Cerveza 8 de 12, pag 1/80
# Cerveza 9 de 12, pag 1/80
# Cerveza 10 de 12, pag 1/80
# Cerveza 11 de 12, pag 1/80
# Cerveza 12 de 12, pag 1/80
# Cerveza 1 de 12, pag 2/80
# Cerveza 2 de 12, pag 2/80
# Cerveza 3 de 12, pag 2/80
# Cerveza 4 de 12, pag 2/80
# Cerveza 5 de 12, pag 2/80
# Cerveza 6 de 12, pag 2/80
# Cerveza 7 de 12, pag 2/80
# Cerveza 8 de 12, pag 2/80
# Cerveza 9 de 12, pag 2/80
# Cerveza 10 de 12, pag 2/80
# Cerveza 11 de 12, pag 2/80
# Cerveza 12 de 12, pag 2/80
# Cerveza 1 de 12, pag 3/80
# Cerveza 2 de 12, pag 3/80
# Cerveza 3 de 12, pag 3/80
# Cerveza 4 de 12, pag 3/80
# Cerveza 5 de 12, pag 3/80
# Cerveza 6 de 12, pag 3/80
# Cerveza 7 de 12, pag 3/80
# Cerveza 8 de 12, pag 3/80
# Cerveza 9 de 12, pag 3/80
# Cerveza 10 de 12, pag 3/80
# Cerveza 11 de 12, pag 3/80
# Cerveza 12 de 12, pag 3/80
# Cerveza 1 de 12, pag 4/80
# Cerveza 2 de 12, pag 4/80
# Cerveza 3 de 12, pag 4/80
# Cerveza 4 de 12, pag 4/80
# Cerveza 5 de 12, pag 4/80
# Cerveza 6 de 12, pag 4/80
# Cerveza 7 de 12, pag 4/80
# Cerveza 8 de 12, pag 4/80
# Cerveza 9 de 12, pag 4/80
# Cerveza 10 de 12, pag 4/80
# Cerveza 11 de 12, pag 4/80
# Cerveza 12 de 12, pag 4/80
# Cerveza 1 de 12, pag 5/80
# Cerveza 2 de 12, pag 5/80
# Cerveza 3 de 12, pag 5/80
# Cerveza 4 de 12, pag 5/80
# Cerveza 5 de 12, pag 5/80
# Cerveza 6 de 12, pag 5/80
# Cerveza 7 de 12, pag 5/80
# Cerveza 8 de 12, pag 5/80
# Cerveza 9 de 12, pag 5/80
# Cerveza 10 de 12, pag 5/80
# Cerveza 11 de 12, pag 5/80
# Cerveza 12 de 12, pag 5/80
# Cerveza 1 de 12, pag 6/80
# Cerveza 2 de 12, pag 6/80
# Cerveza 3 de 12, pag 6/80
# Cerveza 4 de 12, pag 6/80
# Cerveza 5 de 12, pag 6/80
# Cerveza 6 de 12, pag 6/80
# Cerveza 7 de 12, pag 6/80
# Cerveza 8 de 12, pag 6/80
# Cerveza 9 de 12, pag 6/80
# Cerveza 10 de 12, pag 6/80
# Cerveza 11 de 12, pag 6/80
# Cerveza 12 de 12, pag 6/80
# Cerveza 1 de 12, pag 7/80
# Cerveza 2 de 12, pag 7/80
# Cerveza 3 de 12, pag 7/80
# Cerveza 4 de 12, pag 7/80
# Cerveza 5 de 12, pag 7/80
# Cerveza 6 de 12, pag 7/80
# Cerveza 7 de 12, pag 7/80
# Cerveza 8 de 12, pag 7/80
# Cerveza 9 de 12, pag 7/80
# Cerveza 10 de 12, pag 7/80
# Cerveza 11 de 12, pag 7/80
# Cerveza 12 de 12, pag 7/80
# Cerveza 1 de 12, pag 8/80
# Cerveza 2 de 12, pag 8/80
# Cerveza 3 de 12, pag 8/80
# Cerveza 4 de 12, pag 8/80
# Cerveza 5 de 12, pag 8/80
# Cerveza 6 de 12, pag 8/80
# Cerveza 7 de 12, pag 8/80
# Cerveza 8 de 12, pag 8/80
# Cerveza 9 de 12, pag 8/80
# Cerveza 10 de 12, pag 8/80
# Cerveza 11 de 12, pag 8/80
# Cerveza 12 de 12, pag 8/80
# Cerveza 1 de 12, pag 9/80
# Cerveza 2 de 12, pag 9/80
# Cerveza 3 de 12, pag 9/80
# Cerveza 4 de 12, pag 9/80
# Cerveza 5 de 12, pag 9/80
# Cerveza 6 de 12, pag 9/80
# Cerveza 7 de 12, pag 9/80
# Cerveza 8 de 12, pag 9/80
# Cerveza 9 de 12, pag 9/80
# Cerveza 10 de 12, pag 9/80
# Cerveza 11 de 12, pag 9/80
# Cerveza 12 de 12, pag 9/80
# Cerveza 1 de 12, pag 10/80
# Cerveza 2 de 12, pag 10/80
# Cerveza 3 de 12, pag 10/80
# Cerveza 4 de 12, pag 10/80
# Cerveza 5 de 12, pag 10/80
# Cerveza 6 de 12, pag 10/80
# Cerveza 7 de 12, pag 10/80
# Cerveza 8 de 12, pag 10/80
# Cerveza 9 de 12, pag 10/80
# Cerveza 10 de 12, pag 10/80
# Cerveza 11 de 12, pag 10/80
# Cerveza 12 de 12, pag 10/80
# Cerveza 1 de 12, pag 11/80
# Cerveza 2 de 12, pag 11/80
# Cerveza 3 de 12, pag 11/80
# Cerveza 4 de 12, pag 11/80
# Cerveza 5 de 12, pag 11/80
# Cerveza 6 de 12, pag 11/80
# Cerveza 7 de 12, pag 11/80
# Cerveza 8 de 12, pag 11/80
# Cerveza 9 de 12, pag 11/80
# Cerveza 10 de 12, pag 11/80
# Cerveza 11 de 12, pag 11/80
# Cerveza 12 de 12, pag 11/80
# Cerveza 1 de 12, pag 12/80
# Cerveza 2 de 12, pag 12/80
# Cerveza 3 de 12, pag 12/80
# Cerveza 4 de 12, pag 12/80
# Cerveza 5 de 12, pag 12/80
# Cerveza 6 de 12, pag 12/80
# Cerveza 7 de 12, pag 12/80
# Cerveza 8 de 12, pag 12/80
# Cerveza 9 de 12, pag 12/80
# Cerveza 10 de 12, pag 12/80
# Cerveza 11 de 12, pag 12/80
# Cerveza 12 de 12, pag 12/80
# Cerveza 1 de 12, pag 13/80
# Cerveza 2 de 12, pag 13/80
# Cerveza 3 de 12, pag 13/80
# Cerveza 4 de 12, pag 13/80
# Cerveza 5 de 12, pag 13/80
# Cerveza 6 de 12, pag 13/80
# Cerveza 7 de 12, pag 13/80
# Cerveza 8 de 12, pag 13/80
# Cerveza 9 de 12, pag 13/80
# Cerveza 10 de 12, pag 13/80
# Cerveza 11 de 12, pag 13/80
# Cerveza 12 de 12, pag 13/80
# Cerveza 1 de 12, pag 14/80
# Cerveza 2 de 12, pag 14/80
# Cerveza 3 de 12, pag 14/80
# Cerveza 4 de 12, pag 14/80
# Cerveza 5 de 12, pag 14/80
# Cerveza 6 de 12, pag 14/80
# Cerveza 7 de 12, pag 14/80
# Cerveza 8 de 12, pag 14/80
# Cerveza 9 de 12, pag 14/80
# Cerveza 10 de 12, pag 14/80
# Cerveza 11 de 12, pag 14/80
# Cerveza 12 de 12, pag 14/80
# Cerveza 1 de 12, pag 15/80
# Cerveza 2 de 12, pag 15/80
# Cerveza 3 de 12, pag 15/80
# Cerveza 4 de 12, pag 15/80
# Cerveza 5 de 12, pag 15/80
# Cerveza 6 de 12, pag 15/80
# Cerveza 7 de 12, pag 15/80
# Cerveza 8 de 12, pag 15/80
# Cerveza 9 de 12, pag 15/80
# Cerveza 10 de 12, pag 15/80
# Cerveza 11 de 12, pag 15/80
# Cerveza 12 de 12, pag 15/80
# Cerveza 1 de 12, pag 16/80
# Cerveza 2 de 12, pag 16/80
# Cerveza 3 de 12, pag 16/80
# Cerveza 4 de 12, pag 16/80
# Cerveza 5 de 12, pag 16/80
# Cerveza 6 de 12, pag 16/80
# Cerveza 7 de 12, pag 16/80
# Cerveza 8 de 12, pag 16/80
# Cerveza 9 de 12, pag 16/80
# Cerveza 10 de 12, pag 16/80
# Cerveza 11 de 12, pag 16/80
# Cerveza 12 de 12, pag 16/80
# Cerveza 1 de 12, pag 17/80
# Cerveza 2 de 12, pag 17/80
# Cerveza 3 de 12, pag 17/80
# Cerveza 4 de 12, pag 17/80
# Cerveza 5 de 12, pag 17/80
# Cerveza 6 de 12, pag 17/80
# Cerveza 7 de 12, pag 17/80
# Cerveza 8 de 12, pag 17/80
# Cerveza 9 de 12, pag 17/80
# Cerveza 10 de 12, pag 17/80
# Cerveza 11 de 12, pag 17/80
# Cerveza 12 de 12, pag 17/80
# Cerveza 1 de 12, pag 18/80
# Cerveza 2 de 12, pag 18/80
# Cerveza 3 de 12, pag 18/80
# Cerveza 4 de 12, pag 18/80
# Cerveza 5 de 12, pag 18/80
# Cerveza 6 de 12, pag 18/80
# Cerveza 7 de 12, pag 18/80
# Cerveza 8 de 12, pag 18/80
# Cerveza 9 de 12, pag 18/80
# Cerveza 10 de 12, pag 18/80
# Cerveza 11 de 12, pag 18/80
# Cerveza 12 de 12, pag 18/80
# Cerveza 1 de 12, pag 19/80
# Cerveza 2 de 12, pag 19/80
# Cerveza 3 de 12, pag 19/80
# Cerveza 4 de 12, pag 19/80
# Cerveza 5 de 12, pag 19/80
# Cerveza 6 de 12, pag 19/80
# Cerveza 7 de 12, pag 19/80
# Cerveza 8 de 12, pag 19/80
# Cerveza 9 de 12, pag 19/80
# Cerveza 10 de 12, pag 19/80
# Cerveza 11 de 12, pag 19/80
# Cerveza 12 de 12, pag 19/80
# Cerveza 1 de 12, pag 20/80
# Cerveza 2 de 12, pag 20/80
# Cerveza 3 de 12, pag 20/80
# Cerveza 4 de 12, pag 20/80
# Cerveza 5 de 12, pag 20/80
# Cerveza 6 de 12, pag 20/80
# Cerveza 7 de 12, pag 20/80
# Cerveza 8 de 12, pag 20/80
# Cerveza 9 de 12, pag 20/80
# Cerveza 10 de 12, pag 20/80
# Cerveza 11 de 12, pag 20/80
# Cerveza 12 de 12, pag 20/80
# Cerveza 1 de 12, pag 21/80
# Cerveza 2 de 12, pag 21/80
# Cerveza 3 de 12, pag 21/80
# Cerveza 4 de 12, pag 21/80
# Cerveza 5 de 12, pag 21/80
# Cerveza 6 de 12, pag 21/80
# Cerveza 7 de 12, pag 21/80
# Cerveza 8 de 12, pag 21/80
# Cerveza 9 de 12, pag 21/80
# Cerveza 10 de 12, pag 21/80
# Cerveza 11 de 12, pag 21/80
# Cerveza 12 de 12, pag 21/80
# Cerveza 1 de 12, pag 22/80
# Cerveza 2 de 12, pag 22/80
# Cerveza 3 de 12, pag 22/80
# Cerveza 4 de 12, pag 22/80
# Cerveza 5 de 12, pag 22/80
# Cerveza 6 de 12, pag 22/80
# Cerveza 7 de 12, pag 22/80
# Cerveza 8 de 12, pag 22/80
# Cerveza 9 de 12, pag 22/80
# Cerveza 10 de 12, pag 22/80
# Cerveza 11 de 12, pag 22/80
# Cerveza 12 de 12, pag 22/80
# Cerveza 1 de 12, pag 23/80
# Cerveza 2 de 12, pag 23/80
# Cerveza 3 de 12, pag 23/80
# Cerveza 4 de 12, pag 23/80
# Cerveza 5 de 12, pag 23/80
# Cerveza 6 de 12, pag 23/80
# Cerveza 7 de 12, pag 23/80
# Cerveza 8 de 12, pag 23/80
# Cerveza 9 de 12, pag 23/80
# Cerveza 10 de 12, pag 23/80
# Cerveza 11 de 12, pag 23/80
# Cerveza 12 de 12, pag 23/80
# Cerveza 1 de 12, pag 24/80
# Cerveza 2 de 12, pag 24/80
# Cerveza 3 de 12, pag 24/80
# Cerveza 4 de 12, pag 24/80
# Cerveza 5 de 12, pag 24/80
# Cerveza 6 de 12, pag 24/80
# Cerveza 7 de 12, pag 24/80
# Cerveza 8 de 12, pag 24/80
# Cerveza 9 de 12, pag 24/80
# Cerveza 10 de 12, pag 24/80
# Cerveza 11 de 12, pag 24/80
# Cerveza 12 de 12, pag 24/80
# Cerveza 1 de 12, pag 25/80
# Cerveza 2 de 12, pag 25/80
# Cerveza 3 de 12, pag 25/80
# Cerveza 4 de 12, pag 25/80
# Cerveza 5 de 12, pag 25/80
# Cerveza 6 de 12, pag 25/80
# Cerveza 7 de 12, pag 25/80
# Cerveza 8 de 12, pag 25/80
# Cerveza 9 de 12, pag 25/80
# Cerveza 10 de 12, pag 25/80
# Cerveza 11 de 12, pag 25/80
# Cerveza 12 de 12, pag 25/80
# Cerveza 1 de 12, pag 26/80
# Cerveza 2 de 12, pag 26/80
# Cerveza 3 de 12, pag 26/80
# Cerveza 4 de 12, pag 26/80
# Cerveza 5 de 12, pag 26/80
# Cerveza 6 de 12, pag 26/80
# Cerveza 7 de 12, pag 26/80
# Cerveza 8 de 12, pag 26/80
# Cerveza 9 de 12, pag 26/80
# Cerveza 10 de 12, pag 26/80
# Cerveza 11 de 12, pag 26/80
# Cerveza 12 de 12, pag 26/80
# Cerveza 1 de 12, pag 27/80
# Cerveza 2 de 12, pag 27/80
# Cerveza 3 de 12, pag 27/80
# Cerveza 4 de 12, pag 27/80
# Cerveza 5 de 12, pag 27/80
# Cerveza 6 de 12, pag 27/80
# Cerveza 7 de 12, pag 27/80
# Cerveza 8 de 12, pag 27/80
# Cerveza 9 de 12, pag 27/80
# Cerveza 10 de 12, pag 27/80
# Cerveza 11 de 12, pag 27/80
# Cerveza 12 de 12, pag 27/80
# Cerveza 1 de 12, pag 28/80
# Cerveza 2 de 12, pag 28/80
# Cerveza 3 de 12, pag 28/80
# Cerveza 4 de 12, pag 28/80
# Cerveza 5 de 12, pag 28/80
# Cerveza 6 de 12, pag 28/80
# Cerveza 7 de 12, pag 28/80
# Cerveza 8 de 12, pag 28/80
# Cerveza 9 de 12, pag 28/80
# Cerveza 10 de 12, pag 28/80
# Cerveza 11 de 12, pag 28/80
# Cerveza 12 de 12, pag 28/80
# Cerveza 1 de 12, pag 29/80
# Cerveza 2 de 12, pag 29/80
# Cerveza 3 de 12, pag 29/80
# Cerveza 4 de 12, pag 29/80
# Cerveza 5 de 12, pag 29/80
# Cerveza 6 de 12, pag 29/80
# Cerveza 7 de 12, pag 29/80
# Cerveza 8 de 12, pag 29/80
# Cerveza 9 de 12, pag 29/80
# Cerveza 10 de 12, pag 29/80
# Cerveza 11 de 12, pag 29/80
# Cerveza 12 de 12, pag 29/80
# Cerveza 1 de 12, pag 30/80
# Cerveza 2 de 12, pag 30/80
# Cerveza 3 de 12, pag 30/80
# Cerveza 4 de 12, pag 30/80
# Cerveza 5 de 12, pag 30/80
# Cerveza 6 de 12, pag 30/80
# Cerveza 7 de 12, pag 30/80
# Cerveza 8 de 12, pag 30/80
# Cerveza 9 de 12, pag 30/80
# Cerveza 10 de 12, pag 30/80
# Cerveza 11 de 12, pag 30/80
# Cerveza 12 de 12, pag 30/80
# Cerveza 1 de 12, pag 31/80
# Cerveza 2 de 12, pag 31/80
# Cerveza 3 de 12, pag 31/80
# Cerveza 4 de 12, pag 31/80
# Cerveza 5 de 12, pag 31/80
# Cerveza 6 de 12, pag 31/80
# Cerveza 7 de 12, pag 31/80
# Cerveza 8 de 12, pag 31/80
# Cerveza 9 de 12, pag 31/80
# Cerveza 10 de 12, pag 31/80
# Cerveza 11 de 12, pag 31/80
# Cerveza 12 de 12, pag 31/80
# Cerveza 1 de 12, pag 32/80
# Cerveza 2 de 12, pag 32/80
# Cerveza 3 de 12, pag 32/80
# Cerveza 4 de 12, pag 32/80
# Cerveza 5 de 12, pag 32/80
# Cerveza 6 de 12, pag 32/80
# Cerveza 7 de 12, pag 32/80
# Cerveza 8 de 12, pag 32/80
# Cerveza 9 de 12, pag 32/80
# Cerveza 10 de 12, pag 32/80
# Cerveza 11 de 12, pag 32/80
# Cerveza 12 de 12, pag 32/80
# Cerveza 1 de 12, pag 33/80
# Cerveza 2 de 12, pag 33/80
# Cerveza 3 de 12, pag 33/80
# Cerveza 4 de 12, pag 33/80
# Cerveza 5 de 12, pag 33/80
# Cerveza 6 de 12, pag 33/80
# Cerveza 7 de 12, pag 33/80
# Cerveza 8 de 12, pag 33/80
# Cerveza 9 de 12, pag 33/80
# Cerveza 10 de 12, pag 33/80
# Cerveza 11 de 12, pag 33/80
# Cerveza 12 de 12, pag 33/80
# Cerveza 1 de 12, pag 34/80
# Cerveza 2 de 12, pag 34/80
# Cerveza 3 de 12, pag 34/80
# Cerveza 4 de 12, pag 34/80
# Cerveza 5 de 12, pag 34/80
# Cerveza 6 de 12, pag 34/80
# Cerveza 7 de 12, pag 34/80
# Cerveza 8 de 12, pag 34/80
# Cerveza 9 de 12, pag 34/80
# Cerveza 10 de 12, pag 34/80
# Cerveza 11 de 12, pag 34/80
# Cerveza 12 de 12, pag 34/80
# Cerveza 1 de 12, pag 35/80
# Cerveza 2 de 12, pag 35/80
# Cerveza 3 de 12, pag 35/80
# Cerveza 4 de 12, pag 35/80
# Cerveza 5 de 12, pag 35/80
# Cerveza 6 de 12, pag 35/80
# Cerveza 7 de 12, pag 35/80
# Cerveza 8 de 12, pag 35/80
# Cerveza 9 de 12, pag 35/80
# Cerveza 10 de 12, pag 35/80
# Cerveza 11 de 12, pag 35/80
# Cerveza 12 de 12, pag 35/80
# Cerveza 1 de 12, pag 36/80
# Cerveza 2 de 12, pag 36/80
# Cerveza 3 de 12, pag 36/80
# Cerveza 4 de 12, pag 36/80
# Cerveza 5 de 12, pag 36/80
# Cerveza 6 de 12, pag 36/80
# Cerveza 7 de 12, pag 36/80
# Cerveza 8 de 12, pag 36/80
# Cerveza 9 de 12, pag 36/80
# Cerveza 10 de 12, pag 36/80
# Cerveza 11 de 12, pag 36/80
# Cerveza 12 de 12, pag 36/80
# Cerveza 1 de 12, pag 37/80
# Cerveza 2 de 12, pag 37/80
# Cerveza 3 de 12, pag 37/80
# Cerveza 4 de 12, pag 37/80
# Cerveza 5 de 12, pag 37/80
# Cerveza 6 de 12, pag 37/80
# Cerveza 7 de 12, pag 37/80
# Cerveza 8 de 12, pag 37/80
# Cerveza 9 de 12, pag 37/80
# Cerveza 10 de 12, pag 37/80
# Cerveza 11 de 12, pag 37/80
# Cerveza 12 de 12, pag 37/80
# Cerveza 1 de 12, pag 38/80
# Cerveza 2 de 12, pag 38/80
# Cerveza 3 de 12, pag 38/80
# Cerveza 4 de 12, pag 38/80
# Cerveza 5 de 12, pag 38/80
# Cerveza 6 de 12, pag 38/80
# Cerveza 7 de 12, pag 38/80
# Cerveza 8 de 12, pag 38/80
# Cerveza 9 de 12, pag 38/80
# Cerveza 10 de 12, pag 38/80
# Cerveza 11 de 12, pag 38/80
# Cerveza 12 de 12, pag 38/80
# Cerveza 1 de 12, pag 39/80
# Cerveza 2 de 12, pag 39/80
# Cerveza 3 de 12, pag 39/80
# Cerveza 4 de 12, pag 39/80
# Cerveza 5 de 12, pag 39/80
# Cerveza 6 de 12, pag 39/80
# Cerveza 7 de 12, pag 39/80
# Cerveza 8 de 12, pag 39/80
# Cerveza 9 de 12, pag 39/80
# Cerveza 10 de 12, pag 39/80
# Cerveza 11 de 12, pag 39/80
# Cerveza 12 de 12, pag 39/80
# Cerveza 1 de 12, pag 40/80
# Cerveza 2 de 12, pag 40/80
# Cerveza 3 de 12, pag 40/80
# Cerveza 4 de 12, pag 40/80
# Cerveza 5 de 12, pag 40/80
# Cerveza 6 de 12, pag 40/80
# Cerveza 7 de 12, pag 40/80
# Cerveza 8 de 12, pag 40/80
# Cerveza 9 de 12, pag 40/80
# Cerveza 10 de 12, pag 40/80
# Cerveza 11 de 12, pag 40/80
# Cerveza 12 de 12, pag 40/80
# Cerveza 1 de 12, pag 41/80
# Cerveza 2 de 12, pag 41/80
# Cerveza 3 de 12, pag 41/80
# Cerveza 4 de 12, pag 41/80
# Cerveza 5 de 12, pag 41/80
# Cerveza 6 de 12, pag 41/80
# Cerveza 7 de 12, pag 41/80
# Cerveza 8 de 12, pag 41/80
# Cerveza 9 de 12, pag 41/80
# Cerveza 10 de 12, pag 41/80
# Cerveza 11 de 12, pag 41/80
# Cerveza 12 de 12, pag 41/80
# Cerveza 1 de 12, pag 42/80
# Cerveza 2 de 12, pag 42/80
# Cerveza 3 de 12, pag 42/80
# Cerveza 4 de 12, pag 42/80
# Cerveza 5 de 12, pag 42/80
# Cerveza 6 de 12, pag 42/80
# Cerveza 7 de 12, pag 42/80
# Cerveza 8 de 12, pag 42/80
# Cerveza 9 de 12, pag 42/80
# Cerveza 10 de 12, pag 42/80
# Cerveza 11 de 12, pag 42/80
# Cerveza 12 de 12, pag 42/80
# Cerveza 1 de 12, pag 43/80
# Cerveza 2 de 12, pag 43/80
# Cerveza 3 de 12, pag 43/80
# Cerveza 4 de 12, pag 43/80
# Cerveza 5 de 12, pag 43/80
# Cerveza 6 de 12, pag 43/80
# Cerveza 7 de 12, pag 43/80
# Cerveza 8 de 12, pag 43/80
# Cerveza 9 de 12, pag 43/80
# Cerveza 10 de 12, pag 43/80
# Cerveza 11 de 12, pag 43/80
# Cerveza 12 de 12, pag 43/80
# Cerveza 1 de 12, pag 44/80
# Cerveza 2 de 12, pag 44/80
# Cerveza 3 de 12, pag 44/80
# Cerveza 4 de 12, pag 44/80
# Cerveza 5 de 12, pag 44/80
# Cerveza 6 de 12, pag 44/80
# Cerveza 7 de 12, pag 44/80
# Cerveza 8 de 12, pag 44/80
# Cerveza 9 de 12, pag 44/80
# Cerveza 10 de 12, pag 44/80
# Cerveza 11 de 12, pag 44/80
# Cerveza 12 de 12, pag 44/80
# Cerveza 1 de 12, pag 45/80
# Cerveza 2 de 12, pag 45/80
# Cerveza 3 de 12, pag 45/80
# Cerveza 4 de 12, pag 45/80
# Cerveza 5 de 12, pag 45/80
# Cerveza 6 de 12, pag 45/80
# Cerveza 7 de 12, pag 45/80
# Cerveza 8 de 12, pag 45/80
# Cerveza 9 de 12, pag 45/80
# Cerveza 10 de 12, pag 45/80
# Cerveza 11 de 12, pag 45/80
# Cerveza 12 de 12, pag 45/80
# Cerveza 1 de 12, pag 46/80
# Cerveza 2 de 12, pag 46/80
# Cerveza 3 de 12, pag 46/80
# Cerveza 4 de 12, pag 46/80
# Cerveza 5 de 12, pag 46/80
# Cerveza 6 de 12, pag 46/80
# Cerveza 7 de 12, pag 46/80
# Cerveza 8 de 12, pag 46/80
# Cerveza 9 de 12, pag 46/80
# Cerveza 10 de 12, pag 46/80
# Cerveza 11 de 12, pag 46/80
# Cerveza 12 de 12, pag 46/80
# Cerveza 1 de 12, pag 47/80
# Cerveza 2 de 12, pag 47/80
# Cerveza 3 de 12, pag 47/80
# Cerveza 4 de 12, pag 47/80
# Cerveza 5 de 12, pag 47/80
# Cerveza 6 de 12, pag 47/80
# Cerveza 7 de 12, pag 47/80
# Cerveza 8 de 12, pag 47/80
# Cerveza 9 de 12, pag 47/80
# Cerveza 10 de 12, pag 47/80
# Cerveza 11 de 12, pag 47/80
# Cerveza 12 de 12, pag 47/80
# Cerveza 1 de 12, pag 48/80
# Cerveza 2 de 12, pag 48/80
# Cerveza 3 de 12, pag 48/80
# Cerveza 4 de 12, pag 48/80
# Cerveza 5 de 12, pag 48/80
# Cerveza 6 de 12, pag 48/80
# Cerveza 7 de 12, pag 48/80
# Cerveza 8 de 12, pag 48/80
# Cerveza 9 de 12, pag 48/80
# Cerveza 10 de 12, pag 48/80
# Cerveza 11 de 12, pag 48/80
# Cerveza 12 de 12, pag 48/80
# Cerveza 1 de 12, pag 49/80
# Cerveza 2 de 12, pag 49/80
# Cerveza 3 de 12, pag 49/80
# Cerveza 4 de 12, pag 49/80
# Cerveza 5 de 12, pag 49/80
# Cerveza 6 de 12, pag 49/80
# Cerveza 7 de 12, pag 49/80
# Cerveza 8 de 12, pag 49/80
# Cerveza 9 de 12, pag 49/80
# Cerveza 10 de 12, pag 49/80
# Cerveza 11 de 12, pag 49/80
# Cerveza 12 de 12, pag 49/80
# Cerveza 1 de 12, pag 50/80
# Cerveza 2 de 12, pag 50/80
# Cerveza 3 de 12, pag 50/80
# Cerveza 4 de 12, pag 50/80
# Cerveza 5 de 12, pag 50/80
# Cerveza 6 de 12, pag 50/80
# Cerveza 7 de 12, pag 50/80
# Cerveza 8 de 12, pag 50/80
# Cerveza 9 de 12, pag 50/80
# Cerveza 10 de 12, pag 50/80
# Cerveza 11 de 12, pag 50/80
# Cerveza 12 de 12, pag 50/80
# Cerveza 1 de 12, pag 51/80
# Cerveza 2 de 12, pag 51/80
# Cerveza 3 de 12, pag 51/80
# Cerveza 4 de 12, pag 51/80
# Cerveza 5 de 12, pag 51/80
# Cerveza 6 de 12, pag 51/80
# Cerveza 7 de 12, pag 51/80
# Cerveza 8 de 12, pag 51/80
# Cerveza 9 de 12, pag 51/80
# Cerveza 10 de 12, pag 51/80
# Cerveza 11 de 12, pag 51/80
# Cerveza 12 de 12, pag 51/80
# Cerveza 1 de 12, pag 52/80
# Cerveza 2 de 12, pag 52/80
# Cerveza 3 de 12, pag 52/80
# Cerveza 4 de 12, pag 52/80
# Cerveza 5 de 12, pag 52/80
# Cerveza 6 de 12, pag 52/80
# Cerveza 7 de 12, pag 52/80
# Cerveza 8 de 12, pag 52/80
# Cerveza 9 de 12, pag 52/80
# Cerveza 10 de 12, pag 52/80
# Cerveza 11 de 12, pag 52/80
# Cerveza 12 de 12, pag 52/80
# Cerveza 1 de 12, pag 53/80
# Cerveza 2 de 12, pag 53/80
# Cerveza 3 de 12, pag 53/80
# Cerveza 4 de 12, pag 53/80
# Cerveza 5 de 12, pag 53/80
# Cerveza 6 de 12, pag 53/80
# Cerveza 7 de 12, pag 53/80
# Cerveza 8 de 12, pag 53/80
# Cerveza 9 de 12, pag 53/80
# Cerveza 10 de 12, pag 53/80
# Cerveza 11 de 12, pag 53/80
# Cerveza 12 de 12, pag 53/80
# Cerveza 1 de 12, pag 54/80
# Cerveza 2 de 12, pag 54/80
# Cerveza 3 de 12, pag 54/80
# Cerveza 4 de 12, pag 54/80
# Cerveza 5 de 12, pag 54/80
# Cerveza 6 de 12, pag 54/80
# Cerveza 7 de 12, pag 54/80
# Cerveza 8 de 12, pag 54/80
# Cerveza 9 de 12, pag 54/80
# Cerveza 10 de 12, pag 54/80
# Cerveza 11 de 12, pag 54/80
# Cerveza 12 de 12, pag 54/80
# Cerveza 1 de 12, pag 55/80
# Cerveza 2 de 12, pag 55/80
# Cerveza 3 de 12, pag 55/80
# Cerveza 4 de 12, pag 55/80
# Cerveza 5 de 12, pag 55/80
# Cerveza 6 de 12, pag 55/80
# Cerveza 7 de 12, pag 55/80
# Cerveza 8 de 12, pag 55/80
# Cerveza 9 de 12, pag 55/80
# Cerveza 10 de 12, pag 55/80
# Cerveza 11 de 12, pag 55/80
# Cerveza 12 de 12, pag 55/80
# Cerveza 1 de 12, pag 56/80
# Cerveza 2 de 12, pag 56/80
# Cerveza 3 de 12, pag 56/80
# Cerveza 4 de 12, pag 56/80
# Cerveza 5 de 12, pag 56/80
# Cerveza 6 de 12, pag 56/80
# Cerveza 7 de 12, pag 56/80
# Cerveza 8 de 12, pag 56/80
# Cerveza 9 de 12, pag 56/80
# Cerveza 10 de 12, pag 56/80
# Cerveza 11 de 12, pag 56/80
# Cerveza 12 de 12, pag 56/80
# Cerveza 1 de 12, pag 57/80
# Cerveza 2 de 12, pag 57/80
# Cerveza 3 de 12, pag 57/80
# Cerveza 4 de 12, pag 57/80
# Cerveza 5 de 12, pag 57/80
# Cerveza 6 de 12, pag 57/80
# Cerveza 7 de 12, pag 57/80
# Cerveza 8 de 12, pag 57/80
# Cerveza 9 de 12, pag 57/80
# Cerveza 10 de 12, pag 57/80
# Cerveza 11 de 12, pag 57/80
# Cerveza 12 de 12, pag 57/80
# Cerveza 1 de 12, pag 58/80
# Cerveza 2 de 12, pag 58/80
# Cerveza 3 de 12, pag 58/80
# Cerveza 4 de 12, pag 58/80
# Cerveza 5 de 12, pag 58/80
# Cerveza 6 de 12, pag 58/80
# Cerveza 7 de 12, pag 58/80
# Cerveza 8 de 12, pag 58/80
# Cerveza 9 de 12, pag 58/80
# Cerveza 10 de 12, pag 58/80
# Cerveza 11 de 12, pag 58/80
# Cerveza 12 de 12, pag 58/80
# Cerveza 1 de 12, pag 59/80
# Cerveza 2 de 12, pag 59/80
# Cerveza 3 de 12, pag 59/80
# Cerveza 4 de 12, pag 59/80
# Cerveza 5 de 12, pag 59/80
# Cerveza 6 de 12, pag 59/80
# Cerveza 7 de 12, pag 59/80
# Cerveza 8 de 12, pag 59/80
# Cerveza 9 de 12, pag 59/80
# Cerveza 10 de 12, pag 59/80
# Cerveza 11 de 12, pag 59/80
# Cerveza 12 de 12, pag 59/80
# Cerveza 1 de 12, pag 60/80
# Cerveza 2 de 12, pag 60/80
# Cerveza 3 de 12, pag 60/80
# Cerveza 4 de 12, pag 60/80
# Cerveza 5 de 12, pag 60/80
# Cerveza 6 de 12, pag 60/80
# Cerveza 7 de 12, pag 60/80
# Cerveza 8 de 12, pag 60/80
# Cerveza 9 de 12, pag 60/80
# Cerveza 10 de 12, pag 60/80
# Cerveza 11 de 12, pag 60/80
# Cerveza 12 de 12, pag 60/80
# Cerveza 1 de 12, pag 61/80
# Cerveza 2 de 12, pag 61/80
# Cerveza 3 de 12, pag 61/80
# Cerveza 4 de 12, pag 61/80
# Cerveza 5 de 12, pag 61/80
# Cerveza 6 de 12, pag 61/80
# Cerveza 7 de 12, pag 61/80
# Cerveza 8 de 12, pag 61/80
# Cerveza 9 de 12, pag 61/80
# Cerveza 10 de 12, pag 61/80
# Cerveza 11 de 12, pag 61/80
# Cerveza 12 de 12, pag 61/80
# Cerveza 1 de 12, pag 62/80
# Cerveza 2 de 12, pag 62/80
# Cerveza 3 de 12, pag 62/80
# Cerveza 4 de 12, pag 62/80
# Cerveza 5 de 12, pag 62/80
# Cerveza 6 de 12, pag 62/80
# Cerveza 7 de 12, pag 62/80
# Cerveza 8 de 12, pag 62/80
# Cerveza 9 de 12, pag 62/80
# Cerveza 10 de 12, pag 62/80
# Cerveza 11 de 12, pag 62/80
# Cerveza 12 de 12, pag 62/80
# Cerveza 1 de 12, pag 63/80
# Cerveza 2 de 12, pag 63/80
# Cerveza 3 de 12, pag 63/80
# Cerveza 4 de 12, pag 63/80
# Cerveza 5 de 12, pag 63/80
# Cerveza 6 de 12, pag 63/80
# Cerveza 7 de 12, pag 63/80
# Cerveza 8 de 12, pag 63/80
# Cerveza 9 de 12, pag 63/80
# Cerveza 10 de 12, pag 63/80
# Cerveza 11 de 12, pag 63/80
# Cerveza 12 de 12, pag 63/80
# Cerveza 1 de 12, pag 64/80
# Cerveza 2 de 12, pag 64/80
# Cerveza 3 de 12, pag 64/80
# Cerveza 4 de 12, pag 64/80
# Cerveza 5 de 12, pag 64/80
# Cerveza 6 de 12, pag 64/80
# Cerveza 7 de 12, pag 64/80
# Cerveza 8 de 12, pag 64/80
# Cerveza 9 de 12, pag 64/80
# Cerveza 10 de 12, pag 64/80
# Cerveza 11 de 12, pag 64/80
# Cerveza 12 de 12, pag 64/80
# Cerveza 1 de 12, pag 65/80
# Cerveza 2 de 12, pag 65/80
# Cerveza 3 de 12, pag 65/80
# Cerveza 4 de 12, pag 65/80
# Cerveza 5 de 12, pag 65/80
# Cerveza 6 de 12, pag 65/80
# Cerveza 7 de 12, pag 65/80
# Cerveza 8 de 12, pag 65/80
# Cerveza 9 de 12, pag 65/80
# Cerveza 10 de 12, pag 65/80
# Cerveza 11 de 12, pag 65/80
# Cerveza 12 de 12, pag 65/80
# Cerveza 1 de 12, pag 66/80
# Cerveza 2 de 12, pag 66/80
# Cerveza 3 de 12, pag 66/80
# Cerveza 4 de 12, pag 66/80
# Cerveza 5 de 12, pag 66/80
# Cerveza 6 de 12, pag 66/80
# Cerveza 7 de 12, pag 66/80
# Cerveza 8 de 12, pag 66/80
# Cerveza 9 de 12, pag 66/80
# Cerveza 10 de 12, pag 66/80
# Cerveza 11 de 12, pag 66/80
# Cerveza 12 de 12, pag 66/80
# Cerveza 1 de 12, pag 67/80
# Cerveza 2 de 12, pag 67/80
# Cerveza 3 de 12, pag 67/80
# Cerveza 4 de 12, pag 67/80
# Cerveza 5 de 12, pag 67/80
# Cerveza 6 de 12, pag 67/80
# Cerveza 7 de 12, pag 67/80
# Cerveza 8 de 12, pag 67/80
# Cerveza 9 de 12, pag 67/80
# Cerveza 10 de 12, pag 67/80
# Cerveza 11 de 12, pag 67/80
# Cerveza 12 de 12, pag 67/80
# Cerveza 1 de 12, pag 68/80
# Cerveza 2 de 12, pag 68/80
# Cerveza 3 de 12, pag 68/80
# Cerveza 4 de 12, pag 68/80
# Cerveza 5 de 12, pag 68/80
# Cerveza 6 de 12, pag 68/80
# Cerveza 7 de 12, pag 68/80
# Cerveza 8 de 12, pag 68/80
# Cerveza 9 de 12, pag 68/80
# Cerveza 10 de 12, pag 68/80
# Cerveza 11 de 12, pag 68/80
# Cerveza 12 de 12, pag 68/80
# Cerveza 1 de 12, pag 69/80
# Cerveza 2 de 12, pag 69/80
# Cerveza 3 de 12, pag 69/80
# Cerveza 4 de 12, pag 69/80
# Cerveza 5 de 12, pag 69/80
# Cerveza 6 de 12, pag 69/80
# Cerveza 7 de 12, pag 69/80
# Cerveza 8 de 12, pag 69/80
# Cerveza 9 de 12, pag 69/80
# Cerveza 10 de 12, pag 69/80
# Cerveza 11 de 12, pag 69/80
# Cerveza 12 de 12, pag 69/80
# Cerveza 1 de 12, pag 70/80
# Cerveza 2 de 12, pag 70/80
# Cerveza 3 de 12, pag 70/80
# Cerveza 4 de 12, pag 70/80
# Cerveza 5 de 12, pag 70/80
# Cerveza 6 de 12, pag 70/80
# Cerveza 7 de 12, pag 70/80
# Cerveza 8 de 12, pag 70/80
# Cerveza 9 de 12, pag 70/80
# Cerveza 10 de 12, pag 70/80
# Cerveza 11 de 12, pag 70/80
# Cerveza 12 de 12, pag 70/80
# Cerveza 1 de 12, pag 71/80
# Cerveza 2 de 12, pag 71/80
# Cerveza 3 de 12, pag 71/80
# Cerveza 4 de 12, pag 71/80
# Cerveza 5 de 12, pag 71/80
# Cerveza 6 de 12, pag 71/80
# Cerveza 7 de 12, pag 71/80
# Cerveza 8 de 12, pag 71/80
# Cerveza 9 de 12, pag 71/80
# Cerveza 10 de 12, pag 71/80
# Cerveza 11 de 12, pag 71/80
# Cerveza 12 de 12, pag 71/80
# Cerveza 1 de 12, pag 72/80
# Cerveza 2 de 12, pag 72/80
# Cerveza 3 de 12, pag 72/80
# Cerveza 4 de 12, pag 72/80
# Cerveza 5 de 12, pag 72/80
# Cerveza 6 de 12, pag 72/80
# Cerveza 7 de 12, pag 72/80
# Cerveza 8 de 12, pag 72/80
# Cerveza 9 de 12, pag 72/80
# Cerveza 10 de 12, pag 72/80
# Cerveza 11 de 12, pag 72/80
# Cerveza 12 de 12, pag 72/80
# Cerveza 1 de 12, pag 73/80
# Cerveza 2 de 12, pag 73/80
# Cerveza 3 de 12, pag 73/80
# Cerveza 4 de 12, pag 73/80
# Cerveza 5 de 12, pag 73/80
# Cerveza 6 de 12, pag 73/80
# Cerveza 7 de 12, pag 73/80
# Cerveza 8 de 12, pag 73/80
# Cerveza 9 de 12, pag 73/80
# Cerveza 10 de 12, pag 73/80
# Cerveza 11 de 12, pag 73/80
# Cerveza 12 de 12, pag 73/80
# Cerveza 1 de 12, pag 74/80
# Cerveza 2 de 12, pag 74/80
# Cerveza 3 de 12, pag 74/80
# Cerveza 4 de 12, pag 74/80
# Cerveza 5 de 12, pag 74/80
# Cerveza 6 de 12, pag 74/80
# Cerveza 7 de 12, pag 74/80
# Cerveza 8 de 12, pag 74/80
# Cerveza 9 de 12, pag 74/80
# Cerveza 10 de 12, pag 74/80
# Cerveza 11 de 12, pag 74/80
# Cerveza 12 de 12, pag 74/80
# Cerveza 1 de 12, pag 75/80
# Cerveza 2 de 12, pag 75/80
# Cerveza 3 de 12, pag 75/80
# Cerveza 4 de 12, pag 75/80
# Cerveza 5 de 12, pag 75/80
# Cerveza 6 de 12, pag 75/80
# Cerveza 7 de 12, pag 75/80
# Cerveza 8 de 12, pag 75/80
# Cerveza 9 de 12, pag 75/80
# Cerveza 10 de 12, pag 75/80
# Cerveza 11 de 12, pag 75/80
# Cerveza 12 de 12, pag 75/80
# Cerveza 1 de 12, pag 76/80
# Cerveza 2 de 12, pag 76/80
# Cerveza 3 de 12, pag 76/80
# Cerveza 4 de 12, pag 76/80
# Cerveza 5 de 12, pag 76/80
# Cerveza 6 de 12, pag 76/80
# Cerveza 7 de 12, pag 76/80
# Cerveza 8 de 12, pag 76/80
# Cerveza 9 de 12, pag 76/80
# Cerveza 10 de 12, pag 76/80
# Cerveza 11 de 12, pag 76/80
# Cerveza 12 de 12, pag 76/80
# Cerveza 1 de 12, pag 77/80
# Cerveza 2 de 12, pag 77/80
# Cerveza 3 de 12, pag 77/80
# Cerveza 4 de 12, pag 77/80
# Cerveza 5 de 12, pag 77/80
# Cerveza 6 de 12, pag 77/80
# Cerveza 7 de 12, pag 77/80
# Cerveza 8 de 12, pag 77/80
# Cerveza 9 de 12, pag 77/80
# Cerveza 10 de 12, pag 77/80
# Cerveza 11 de 12, pag 77/80
# Cerveza 12 de 12, pag 77/80
# Cerveza 1 de 12, pag 78/80
# Cerveza 2 de 12, pag 78/80
# Cerveza 3 de 12, pag 78/80
# Cerveza 4 de 12, pag 78/80
# Cerveza 5 de 12, pag 78/80
# Cerveza 6 de 12, pag 78/80
# Cerveza 7 de 12, pag 78/80
# Cerveza 8 de 12, pag 78/80
# Cerveza 9 de 12, pag 78/80
# Cerveza 10 de 12, pag 78/80
# Cerveza 11 de 12, pag 78/80
# Cerveza 12 de 12, pag 78/80
# Cerveza 1 de 12, pag 79/80
# Cerveza 2 de 12, pag 79/80
# Cerveza 3 de 12, pag 79/80
# Cerveza 4 de 12, pag 79/80
# Cerveza 5 de 12, pag 79/80
# Cerveza 6 de 12, pag 79/80
# Cerveza 7 de 12, pag 79/80
# Cerveza 8 de 12, pag 79/80
# Cerveza 9 de 12, pag 79/80
# Cerveza 10 de 12, pag 79/80
# Cerveza 11 de 12, pag 79/80
# Cerveza 12 de 12, pag 79/80
# Cerveza 1 de 10, pag 80/80
# Cerveza 2 de 10, pag 80/80
# Cerveza 3 de 10, pag 80/80
# Cerveza 4 de 10, pag 80/80
# Cerveza 5 de 10, pag 80/80
# Cerveza 6 de 10, pag 80/80
# Cerveza 7 de 10, pag 80/80
# Cerveza 8 de 10, pag 80/80
# Cerveza 9 de 10, pag 80/80
# Cerveza 10 de 10, pag 80/80

# %%
df = pd.DataFrame([[x[0][1],
                    x[1][1],
                    x[2][1],
                    x[3][1],
                    x[4][1],
                    x[5][1],
                    x[6][1]] for x in lista_cervezas],
                    columns = ['id', 'name', 'price', 'short drecript', 'image', 'brand', 'features'])

df.to_csv('df_labirratorium.csv', sep = ';')
df.head(30)
# Out:
#         id                                               name  price  \
# 0    lbt_1                             Boon Oude Kriek 37,5cl   7.15
# 1    lbt_2                           Störtebeker Schwarz-Bier    2.4
# 2    lbt_3                                              Orval    2.8
# 3    lbt_4                          Augustiner Lagerbier Hell    2.5
# 4    lbt_5                 Schneider Aventinus Weizen-Eisbock    2.7
# 5    lbt_6                 Aecht Schlenkerla Rauchbier Weizen    2.5
# 6    lbt_7                          Samuel Adams Boston Lager    2.4
# 7    lbt_8                     Laugar EPA! Euskadiko Pale Ale   2.65
# 8    lbt_9                                   Westmalle Dubbel    2.3
# 9   lbt_10                              Duchesse De Bourgogne   2.95
# 10  lbt_11                            Tripel Karmeliet 33 cl.    2.5
# 11  lbt_12                              Weihenstephaner Vitus    2.8
# 12  lbt_13                                      Anchor Porter   2.95
# 13  lbt_14  Blaugies / Hill Farmstead La Vermontoise 37,5 cl.    6.6
# 14  lbt_15                Oud Beersel Oude Kriek Vieille 75cl  14.95
# 15  lbt_16                      Boon Oude Geuze Boon 37,5 cl.   5.15
# 16  lbt_17                          Weihenstephaner Korbinian   2.95
# 17  lbt_18                 Aecht Schlenkerla Rauchbier Märzen    2.4
# 18  lbt_19                        Samuel Smith Imperial Stout    3.3
# 19  lbt_20                                   Westmalle Tripel   2.75
# 20  lbt_21                    Chimay Azul Grande Réserve 75cl   7.55
# 21  lbt_22                         Lindemans Framboise 25 cl.    2.4
# 22  lbt_23                                        Achel Brune   2.75
# 23  lbt_24                                     Laugar Ziztada    5.7
# 24  lbt_25                                 Ayinger Celebrator   2.25
# 25  lbt_26                                    Pilsner Urquell    1.6
# 26  lbt_27             Aecht Schlenkerla Rauchbier Doppelbock   3.05
# 27  lbt_28                   Flying Dog Doggie Style Pale Ale   2.95
# 28  lbt_29                             Straffe Hendrik Tripel    3.5
# 29  lbt_30                                  Chimay Azul 33 cl    3.2
#
#                                        short drecript  \
# 0                                      Lambic / Kriek
# 1                 Cerveza negra de baja fermentación
# 2                                    Belgian Pale Ale
# 3                                      Lager / Helles
# 4   Cerveza de color medio oscuro, aromas alcohóli...
# 5
# 6   Cerveza de baja fermentación (Lager) de color ...
# 7                                   American Pale Ale
# 8                                              Dubbel
# 9                         Oud Bruin/ Flanders Red Ale
# 10                                             Tripel
# 11                                         Weizenbock
# 12                                             Porter
# 13                                             Saison
# 14                                     Lambik / Kriek
# 15                                    Lambic / Gueuze
# 16                                         Doppelbock
# 17                                  Rauchbier / Mazen
# 18                                     Imperial Stout
# 19                                             Tripel
# 20                                 Belgian Strong Ale
# 21                                 Lambic / Framboise
# 22                                     Belgian Dubbel
# 23                                        Session IPA
# 24                                         Doppelbock
# 25                                            Pilsner
# 26                             Rauchbier / Doppelbock
# 27                                  American Pale Ale
# 28              Cerveza rubia estilo Tripel de abadía
# 29                            Belgian Strong Dark Ale
#
#                                                 image  \
# 0   https://www.labirratorium.com/19351-large_defa...
# 1   https://www.labirratorium.com/488-large_defaul...
# 2   https://www.labirratorium.com/385-large_defaul...
# 3   https://www.labirratorium.com/367-large_defaul...
# 4   https://www.labirratorium.com/366-large_defaul...
# 5   https://www.labirratorium.com/364-large_defaul...
# 6   https://www.labirratorium.com/343-large_defaul...
# 7   https://www.labirratorium.com/11103-large_defa...
# 8   https://www.labirratorium.com/102-large_defaul...
# 9   https://www.labirratorium.com/12300-large_defa...
# 10  https://www.labirratorium.com/81-large_default...
# 11  https://www.labirratorium.com/43-large_default...
# 12  https://www.labirratorium.com/41-large_default...
# 13  https://www.labirratorium.com/21794-large_defa...
# 14  https://www.labirratorium.com/620-large_defaul...
# 15  https://www.labirratorium.com/618-large_defaul...
# 16  https://www.labirratorium.com/365-large_defaul...
# 17  https://www.labirratorium.com/12653-large_defa...
# 18  https://www.labirratorium.com/131-large_defaul...
# 19  https://www.labirratorium.com/103-large_defaul...
# 20  https://www.labirratorium.com/67-large_default...
# 21  https://www.labirratorium.com/62-large_default...
# 22  https://www.labirratorium.com/12481-large_defa...
# 23  https://www.labirratorium.com/10076-large_defa...
# 24  https://www.labirratorium.com/899-large_defaul...
# 25  https://www.labirratorium.com/848-large_defaul...
# 26  https://www.labirratorium.com/777-large_defaul...
# 27  https://www.labirratorium.com/238-large_defaul...
# 28  https://www.labirratorium.com/89-large_default...
# 29  https://www.labirratorium.com/87-large_default...
#
#                                                 brand  \
# 0                                   Brouwerij F. Boon
# 1                                         Störtebeker
# 2                                               Orval
# 3                                          Augustiner
# 4                                           Schneider
# 5                                     Brauerei Heller
# 6                                        Samuel Adams
# 7                                              Laugar
# 8                                       Van Westmalle
# 9                                           Verhaeghe
# 10                      Brouwerij Bosteels (AB InBev)
# 11                                      Weihenstephan
# 12                   Anchor Brewing Company (Sapporo)
# 13                                           Blaugies
# 14                                        Oud Beersel
# 15                                  Brouwerij F. Boon
# 16                                      Weihenstephan
# 17                                    Brauerei Heller
# 18                                       Samuel Smith
# 19                                      Van Westmalle
# 20                                             Chimay
# 21                                          Lindemans
# 22  Brouwerij der Trappistenabdij De Achelse Kluis...
# 23                                             Laugar
# 24                                            Ayinger
# 25     Pilsner Urquell- Plzensky Prazdroj (SABMiller)
# 26                                        Schlenkerla
# 27                                         Flying Dog
# 28                      De Halve Maan-Straffe Hendrik
# 29                                             Chimay
#
#                                              features
# 0   {'Estilo': 'KRIEK', 'Origen': 'Bélgica', '% Al...
# 1   {'Estilo': 'SCHWARZBIER', 'Origen': 'Alemania'...
# 2   {'Estilo': 'BELGIAN PALE ALE', 'Origen': 'Bélg...
# 3   {'Estilo': 'MUNICH HELLES', 'Origen': 'Alemani...
# 4   {'Origen': 'Alemania', '% Alc.': '12', 'Volume...
# 5   {'Estilo': 'RAUCHBIER', 'Origen': 'Alemania', ...
# 6   {'Estilo': 'AMERICAN LAGER', 'Origen': 'EEUU',...
# 7   {'Estilo': 'APA (AMERICAN PALE ALE)', 'Origen'...
# 8   {'Estilo': 'DUBBEL', 'Origen': 'Bélgica', '% A...
# 9   {'Estilo': 'FLANDERS RED ALE
# OUD BRUIN
# Oud Bru...
# 10  {'Origen': 'Bélgica', '% Alc.': '8.4
# ALTO (6-9...
# 11  {'Estilo': 'TRIGO ALEMÁN (WEIZENDOPPELBOCK)', ...
# 12  {'Estilo': 'AMERICAN PORTER', 'Origen': 'Estad...
# 13  {'Estilo': 'SAISON / FARMHOUSE ALE', 'Origen':...
# 14  {'Estilo': 'KRIEK', 'Origen': 'Belgica', '% Al...
# 15  {'Estilo': 'GUEUZE', 'Origen': 'Bélgica', '% A...
# 16  {'Estilo': 'DOPPELBOCK', 'Origen': 'Alemania',...
# 17  {'Estilo': 'RAUCHBIER', 'Origen': 'Alemania', ...
# 18  {'Estilo': 'IMPERIAL STOUT', 'Origen': 'Inglat...
# 19  {'Estilo': 'TRIPEL', 'Origen': 'Bélgica', '% A...
# 20  {'Estilo': 'BELGIAN DARK STRONG ALE', 'Origen'...
# 21  {'Estilo': 'FRAMBOISE', 'Origen': 'Bélgica', '...
# 22  {'Estilo': 'DUBBEL', 'Origen': 'Bélgica', '% A...
# 23  {'Estilo': 'SESSION IPA', 'Origen': 'Bizkaia',...
# 24  {'Estilo': 'DOPPELBOCK', 'Origen': 'Alemania',...
# 25  {'Estilo': 'PILSNER ', 'Origen': 'República Ch...
# 26  {'Estilo': 'RAUCHBIER', 'Origen': 'Alemania', ...
# 27  {'Estilo': 'APA (AMERICAN PALE ALE)', 'Origen'...
# 28  {'Estilo': 'TRIPEL', 'Origen': 'Bélgica', '% A...
# 29  {'Origen': 'Bélgica', '% Alc.': '9
# ALTO (6-9%)...

# %% [markdown]
# ### Ya sabemos obtener todos los datos que nos interesan de una cerveza, ahora tenemos que aplicar esta lógica para obtener todas las demás

# %% [markdown]
# ### FBI: Top ten criminals
#
# #### Queremos guardar las imágenes de cada fugitivo y que el nombre de cada archivo sea el nombre del fugitivo:

# %%
fbi_url = 'https://www.fbi.gov/wanted/topten'
