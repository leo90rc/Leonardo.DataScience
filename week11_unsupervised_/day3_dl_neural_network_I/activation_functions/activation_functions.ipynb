# %% [markdown]
# ### ReLu

# %%
def ReLU(x):
    return (abs(x) + x) / 2

# %%
ReLU(32626)
# Out:
# 32626.0

# %% [markdown]
# ### Sigmoid

# %%
import math

def sigmoid(x):
  return 1 / (1 + math.exp(-x))

# %%
sigmoid(-590)
# Out:
# 5.837886901742308e-257

# %% [markdown]
# ### Hyperbolic tangent

# %%
import tensorflow as tf 
# tf.keras.activations.tanh()

# %% [markdown]
# ## TESTING

# %%
import numpy as np
import matplotlib.pylab as plt

_ = np.arange(10)
x_ = np.random.random(10) -5
x_
# Out:
# array([-4.57699072, -4.32163722, -4.64795719, -4.86743326, -4.60508268,
#        -4.98371839, -4.55738034, -4.37824975, -4.4112653 , -4.05956476])

# %%
plt.plot(_, x_)

# %%
plt.plot(_, ReLU(x_))

# %%
y_sigmoid_ = [sigmoid(x) for x in x_]
print(y_sigmoid_)
plt.scatter(x_, y_sigmoid_)
# Out:
# [0.01018108202689049, 0.013104128293294165, 0.009490227104937096, 0.007634354372592693, 0.00990184793931771, 0.006801965990052914, 0.010380614434711955, 0.01239181651007903, 0.011994200865371632, 0.016963792049150456]

# %%
tf.keras.activations.tanh(-1.)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=-0.7615942>
