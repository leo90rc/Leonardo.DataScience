# %% [markdown]
#    #                                                  Titanic Exercise II
#    #### Practice matplotlib & seaborn

# %% [markdown]
# ![titanic](https://userscontent2.emaze.com/images/a5f68f37-6349-4065-a1fc-921cbe7401b2/958230111417e36d6b3c67ffd7bc3494.jpeg)

# %% [markdown]
# First of all, import the needed libraries.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# visualisation libraries

# %% [markdown]
# 1. Read the `.csv` file you generated in **1_Titanic-Pandas** `titanic_cleaned.csv` and call the variable `titanic`.
#
# Help: If you didn't get to the point in which you should have saved the file, ask the instructor.

# %%
filename = "./data/titanic_cleaned.csv"

# %%
#your code
titanic = pd.read_csv(filename)
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#       gender    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.00      0      0   24160  211.3375       B5        S    2
# 1       male   0.92      1      2  113781  151.5500  C22 C26        S   11
# 2     female   2.00      1      2  113781  151.5500  C22 C26        S  NaN
# 3       male  30.00      1      2  113781  151.5500  C22 C26        S  NaN
# 4     female  25.00      1      2  113781  151.5500  C22 C26        S  NaN
# ...      ...    ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female  14.50      1      0    2665   14.4542      NaN        C  NaN
# 1305  female    NaN      1      0    2665   14.4542      NaN        C  NaN
# 1306    male  26.50      0      0    2656    7.2250      NaN        C  NaN
# 1307    male  27.00      0      0    2670    7.2250      NaN        C  NaN
# 1308    male  29.00      0      0  315082    7.8750      NaN        S  NaN
#
#        body                        home.dest
# 0       NaN                     St Louis, MO
# 1       NaN  Montreal, PQ / Chesterville, ON
# 2       NaN  Montreal, PQ / Chesterville, ON
# 3     135.0  Montreal, PQ / Chesterville, ON
# 4       NaN  Montreal, PQ / Chesterville, ON
# ...     ...                              ...
# 1304  328.0                              NaN
# 1305    NaN                              NaN
# 1306  304.0                              NaN
# 1307    NaN                              NaN
# 1308    NaN                              NaN
#
# [1309 rows x 14 columns]

# %% [markdown]
# 2. Using matplotlib find the appropriate visualization to show the distribution of the column `age`

# %%
#your code here
sns.set(style='ticks')
plt.hist(titanic['age'], bins= 8)
plt.xlabel('age')
plt.ylabel('number')
plt.title('age distribution')
plt.xlim(0)
# Out:
# (0.0, 83.99150000000002)

# %% [markdown]
# 3. Now use seaborn to show the distribution of the column `age`.

# %%
#your code here
sns.set(style='ticks')
sns.distplot(titanic['age'], bins= 8, kde= False)
sns.despine()
# Out:
# C:\Users\LeoFr\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# 4. Use subplots to plot the distribution of the Age variable with bins equal to 10, 20 and 50.
#
# Use `sns.histplot()` for that aim.

# %%
#your code here
plt.figure(figsize = (8,10))
plt.subplot(3,1,1)
sns.histplot(titanic.age, bins= 10)
plt.xlim(0)

plt.subplot(3,1,2)
sns.histplot(titanic.age, bins= 20)
plt.xlim(0)

plt.subplot(3,1,3)
sns.histplot(titanic.age, bins= 50)
plt.xlim(0)
# Out:
# (0.0, 83.9915)

# %% [markdown]
# 5. Whether the bin size affects your plot? Why?

# %%
#your comment here
# it affects in that ages are distributed in more bin when number of bins is larger

# %% [markdown]
# 6. Using matplotlib find the appropriate plot to visualize the column `'gender'`

# %%
# your code here
plt.hist(titanic['sex'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sex'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-80f4c8995b4d> in <module>
#       1 # your code here
# ----> 2 plt.hist(titanic['sex'])
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'sex'

# %% [markdown]
# 7. What if you also plot the column `'gender'` using the function [`countplot`](https://seaborn.pydata.org/generated/seaborn.countplot.html) from the library [`seaborn`](https://seaborn.pydata.org/)?

# %%
#your code
sns.countplot(titanic['sex'])
# Out:
# C:\Users\jarai\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %% [markdown]
# 6. Using the function [`catplot`](https://seaborn.pydata.org/generated/seaborn.catplot.html) from the library `seaborn`, find out if the hypothesis _"Women are more likely to survive shipwrecks"_ is true or not.
#
# You should get something like this:

# %% [markdown]
# ![catplot](img/catplot.png)

# %%
#your code
sns.catplot(data= titanic, x='sex', y='survived', kind='bar')

# %% [markdown]
# 7. Use the appropriate plot to visualize the column `pclass`.

# %%
#your code
sns.countplot(titanic.pclass)
# Out:
# C:\Users\jarai\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='pclass', ylabel='count'>

# %% [markdown]
# 8. We would like to have in one single plot the summary statistics of the feature `age`. Choose the appropriate plot to show below.

# %%
#your code
sns.violinplot(titanic.age)
# Out:
# C:\Users\jarai\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='age'>

# %%
sns.boxenplot(titanic.age)
# Out:
# C:\Users\jarai\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='age'>

# %% [markdown]
# 9. What does the previous plot tell you about the feature Age? Comment.

# %%
# your comment here
# the gross part of the population was between 20 and 40 years old

# %% [markdown]
# 10. Now in addition to the summary statistics, we also want to visualize the distribution of `age`. Choose the appropriate plot to show below.

# %%
#your code
sns.distplot(titanic.age)
# Out:
# C:\Users\jarai\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %% [markdown]
# 11. Use the appropriate plot to display the distributions of `age` in relation to `gender`.
#
# Hint: use Facetgrid to display the distribution of age for each categorical value of gender.

# %%
#your code
x =sns.FacetGrid(data= titanic, col= 'sex')
x.map(sns.histplot, 'age')

# %% [markdown]
# 12. Using [`kdeplot`]("https://seaborn.pydata.org/generated/seaborn.kdeplot.html") from `seaborn` represent those who not survived distributed by age.
#
# Hint: First you should "filter" the `titanic` dataset where the column "survived" is 0, indexing the column `"age"` only.
#
# Arguments you should pass to the function:
#
#     - color = "red"
#     - label = "Not Survived"
#     - shade = True
#
# You should get something like this:

# %%
survived = titanic[titanic['survived'] == 1]['age']
not_survived = titanic[titanic['survived'] == 0]['age']

# %%
survived
# Out:
# 0       29.00
# 1        0.92
# 5       48.00
# 6       63.00
# 8       53.00
#         ...
# 1261    63.00
# 1277    22.00
# 1286    38.00
# 1290    47.00
# 1300    15.00
# Name: age, Length: 500, dtype: float64

# %% [markdown]
# ![kdeplot](img/kdeplot.png)

# %%
#your code 

sns.kdeplot(not_survived, color='red', fill=True, legend= True)
sns.kdeplot(survived, color='green', fill= True, legend= True)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %% [markdown]
# 13. Using Seaborn plot the correlation matrix of various features.
#
# Hint: search how to use `heatmap`

# %%
titanic_correlation = titanic.corr()

# %%
sns.heatmap(titanic_correlation, annot= True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# 14. According to the previous plot, what are the most correlated feature? Comment.

# %%
#your comment here
# The most correlated features are parch and siblings.abs
# Is interesting to see that the biggest negative correlation is between fare and class
