# %% [markdown]
# # Tips **

# %% [markdown]
# ### Step 1. Import the necessary libraries:

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# print the graphs in the notebook
# %matplotlib inline

# set seaborn style to white
sns.set_style("white")

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Tips/tips.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called tips

# %%
tips = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Tips/tips.csv')
tips.head()
# Out:
#    Unnamed: 0  total_bill   tip     sex smoker  day    time  size
# 0           0       16.99  1.01  Female     No  Sun  Dinner     2
# 1           1       10.34  1.66    Male     No  Sun  Dinner     3
# 2           2       21.01  3.50    Male     No  Sun  Dinner     3
# 3           3       23.68  3.31    Male     No  Sun  Dinner     2
# 4           4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Step 4. Delete the Unnamed 0 column

# %%
tips.drop(columns='Unnamed: 0', inplace= True)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ### Step 5. Plot the total_bill column histogram

# %%
plt.figure()
sns.distplot(tips.total_bill).set(title = "Total Bill", xlabel = 'Value', ylabel = 'Frecuency')

sns.despine()
# Out:
# C:\Users\LeoFr\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Step 6. Create a scatter plot presenting the relationship between total_bill and tip

# %%
sns.jointplot(data = tips, x="total_bill", y='tip', alpha = 0.8 )

# %% [markdown]
# ### Step 7.  Create one image with the relationship of `total_bill`, `tip` and `size`.
# #### Hint: It is just one function.

# %%
sns.pairplot(tips)

# %% [markdown]
# ### Step 8. Present the relationship between days and total_bill value

# %%
sns.catplot(x = 'day', y = 'total_bill', data = tips)

# %% [markdown]
# ### Step 9. Create a scatter plot with the day as the y-axis and tip as the x-axis, differ the dots by sex

# %%
sns.catplot(x = 'tip', y = 'day', hue = 'sex', data = tips, palette= ('blue', 'green'))

# %%
sns.relplot(x = tips.tip , y = tips.day, hue= tips.sex)

# %% [markdown]
# ### Step 10.  Create a box plot presenting the total_bill per day differetiation the time (Dinner or Lunch)

# %%
sns.catplot(x="day", y="total_bill", hue="time", kind="box", data=tips, palette=('blue', 'green'))

# %% [markdown]
# ### Step 11. Create two histograms of the tip value based for Dinner and Lunch. They must be side by side.

# %%
g = sns.FacetGrid(tips, col= 'time')
g.map(sns.histplot, 'tip')

# %%
fig

# %%
fig, ax = plt.subplots(1,2, sharey=True, figsize=(10, 5))
ax[0].hist(tips[tips['time'] == 'Dinner']['tip'])
ax[0].set_title('time = Dinner')
ax[1].hist(tips[tips['time'] == 'Lunch']['tip'])
ax[1].set_title('time = Lunch')
# Out:
# Text(0.5, 1.0, 'time = Lunch')

# %%
plt.subplot(1,2,1)
sns.distplot(tips[tips['time'] == 'Dinner']['tip'], kde= False, bins = 10)
plt.subplot(1,2,2, sharex)
sns.distplot(tips[tips['time'] == 'Lunch']['tip'], kde = False, bins = 10)
# Out:
# C:\Users\LeoFr\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-80-4be1850379f5> in <module>
#       1 plt.subplot(1,2,1)
#       2 sns.distplot(tips[tips['time'] == 'Dinner']['tip'], kde= False, bins = 10)
# ----> 3 plt.subplot(1,2,2, sharex= True)
#       4 sns.distplot(tips[tips['time'] == 'Lunch']['tip'], kde = False, bins = 10)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\matplotlib\pyplot.py in subplot(*args, **kwargs)
#    1256     else:
# ...

# %%
g = sns.FacetGrid(tips, col= 'time')
g.map(sns.histplot, 'tip', bins = 10)

# %%
g = sns.FacetGrid(tips, col= 'time')
g.map(plt.hist, 'tip')

# %% [markdown]
# ### Step 12. Create two scatterplots graphs, one for Male and another for Female, presenting the total_bill value and tip relationship, differing by smoker or no smoker
# ### They must be side by side.

# %%
h = sns.FacetGrid(tips, col= 'sex', hue= 'smoker', palette=('green', 'blue'))
h.map(plt.scatter, 'total_bill','tip')
h.add_legend()

# %%
h.map()

# %%
g = sns.FacetGrid(tips, col = 'sex', hue= 'smoker', palette=('green', 'blue'))
g.map_dataframe(sns.scatterplot, x = 'total_bill', y = 'tip', alpha = .6)
g.set_axis_labels('total_bill', 'tip')
g.add_legend()

# %%
g = sns.FacetGrid(tips, col = 'sex', hue= 'smoker', palette=('green', 'blue'))
g.map_dataframe(plt.scatter,'total_bill','tip', alpha = 0.6)
g.add_legend()
