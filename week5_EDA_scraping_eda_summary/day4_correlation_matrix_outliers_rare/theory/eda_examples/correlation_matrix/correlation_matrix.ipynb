# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# MPG: Millas por galón
# MSRP: Precio de venta
df = pd.read_csv("HP_engine.csv")
df.sample(10)
# Out:
#              Make                Model  Year                Engine Fuel Type  \
# 3005    Chevrolet             Corvette  2017  premium unleaded (recommended)
# 5128     Infiniti                  G20  2002                regular unleaded
# 3822   Oldsmobile  Eighty-Eight Royale  1995                regular unleaded
# 7149      Lincoln            Navigator  2015                regular unleaded
# 7251        Dodge                Nitro  2011                regular unleaded
# 5100     Infiniti              G Sedan  2011  premium unleaded (recommended)
# 10461      Nissan                Titan  2017                regular unleaded
# 7266       Nissan                NV200  2016                regular unleaded
# 2833     Plymouth                 Colt  1994                regular unleaded
# 4048       Suzuki              Equator  2012                regular unleaded
#
#        Engine HP  Engine Cylinders Transmission Type      Driven_Wheels  \
# 3005       455.0               8.0            MANUAL   rear wheel drive
# 5128       145.0               4.0         AUTOMATIC  front wheel drive
# 3822       225.0               6.0         AUTOMATIC  front wheel drive
# 7149       365.0               6.0         AUTOMATIC   rear wheel drive
# 7251       260.0               6.0         AUTOMATIC   four wheel drive
# 5100       328.0               6.0         AUTOMATIC   rear wheel drive
# 10461      390.0               8.0         AUTOMATIC   four wheel drive
# 7266       131.0               4.0         AUTOMATIC  front wheel drive
# 2833       113.0               4.0            MANUAL  front wheel drive
# 4048       152.0               4.0            MANUAL   rear wheel drive
#
#        Number of Doors        Market Category Vehicle Size  \
# 3005               2.0       High-Performance      Compact
# 5128               4.0                 Luxury      Compact
# 3822               4.0                    NaN        Large
# 7149               4.0                 Luxury        Large
# 7251               4.0  Crossover,Performance      Midsize
# 5100               4.0     Luxury,Performance      Midsize
# 10461              4.0                    NaN        Large
# 7266               4.0                    NaN      Compact
# 2833               4.0                    NaN      Compact
# 4048               4.0                    NaN      Compact
#
#              Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# 3005                 Coupe           25        16        1385  59905
# 5128                 Sedan           23        20         190  22195
# 3822                 Sedan           26        17          26   2000
# 7149               4dr SUV           22        16          61  61480
# 7251               4dr SUV           21        16        1851  27995
# 5100                 Sedan           27        19         190  44150
# 10461      Crew Cab Pickup           21        15        2009  49460
# 7266         Cargo Minivan           26        24        2009  21760
# 2833                 Wagon           27        21         535   2000
# 4048   Extended Cab Pickup           23        19         481  19299

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
# Make                 11914 non-null object
# Model                11914 non-null object
# Year                 11914 non-null int64
# Engine Fuel Type     11911 non-null object
# Engine HP            11845 non-null float64
# Engine Cylinders     11884 non-null float64
# Transmission Type    11914 non-null object
# Driven_Wheels        11914 non-null object
# Number of Doors      11908 non-null float64
# Market Category      8172 non-null object
# Vehicle Size         11914 non-null object
# Vehicle Style        11914 non-null object
# highway MPG          11914 non-null int64
# city mpg             11914 non-null int64
# Popularity           11914 non-null int64
# MSRP                 11914 non-null int64
# dtypes: float64(3), int64(5), object(8)
# memory usage: 1.5+ MB

# %%
df.shape
# Out:
# (11914, 16)

# %%
# Correlación de Pearson
# -1 < r < 1

# Finding the relations between the variables.
plt.figure(figsize=(15,10))
c = df.corr()
sns.heatmap(c, cmap="BrBG",annot=True)

# %% [markdown]
# Correlación positiva --> (>0.5)
#
# Correlación negativa --> (<-0.45)

# %%
df.corr()

# %%
plt.figure(figsize=(5,4))
c = df.corr()
sns.heatmap(c, cmap="BrBG",annot=True)

# %%
sns.heatmap(df.corr(), cmap="BrBG", annot=True)

# %% [markdown]
# ### Correlación de Pearson
# #### -1 < r < 1
# ![](correlation-examples.svg)

# %%
sns.pairplot(data=df, kind="reg")

# %%
sns.pairplot(data=df, kind="reg")

# %%
sns.regplot(x="Engine HP", y="MSRP", data=df)

# %%
sns.regplot(x="MSRP", y="Engine HP", data=df)
